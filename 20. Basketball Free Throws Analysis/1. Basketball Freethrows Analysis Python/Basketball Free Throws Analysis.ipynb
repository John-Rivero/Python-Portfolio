# %%
import numpy as np
import matplotlib.pyplot as plt

#Seasons
Seasons = ["2005","2006","2007","2008","2009","2010","2011","2012","2013","2014"]
Sdict = {"2005":0,"2006":1,"2007":2,"2008":3,"2009":4,"2010":5,"2011":6,"2012":7,"2013":8,"2014":9}

#Players
Players = ["KobeBryant","JoeJohnson","LeBronJames","CarmeloAnthony","DwightHoward","ChrisBosh","ChrisPaul","KevinDurant","DerrickRose","DwayneWade"]
Pdict = {"KobeBryant":0,"JoeJohnson":1,"LeBronJames":2,"CarmeloAnthony":3,"DwightHoward":4,"ChrisBosh":5,"ChrisPaul":6,"KevinDurant":7,"DerrickRose":8,"DwayneWade":9}


#Games 
KobeBryant_G = [80,77,82,82,73,82,58,78,6,35]
JoeJohnson_G = [82,57,82,79,76,72,60,72,79,80]
LeBronJames_G = [79,78,75,81,76,79,62,76,77,69]
CarmeloAnthony_G = [80,65,77,66,69,77,55,67,77,40]
DwightHoward_G = [82,82,82,79,82,78,54,76,71,41]
ChrisBosh_G = [70,69,67,77,70,77,57,74,79,44]
ChrisPaul_G = [78,64,80,78,45,80,60,70,62,82]
KevinDurant_G = [35,35,80,74,82,78,66,81,81,27]
DerrickRose_G = [40,40,40,81,78,81,39,0,10,51]
DwayneWade_G = [75,51,51,79,77,76,49,69,54,62]
#Matrix
Games = np.array([KobeBryant_G, JoeJohnson_G, LeBronJames_G, CarmeloAnthony_G, DwightHoward_G, ChrisBosh_G, ChrisPaul_G, KevinDurant_G, DerrickRose_G, DwayneWade_G])


#Field Goals
KobeBryant_FG = [978,813,775,800,716,740,574,738,31,266]
JoeJohnson_FG = [632,536,647,620,635,514,423,445,462,446]
LeBronJames_FG = [875,772,794,789,768,758,621,765,767,624]
CarmeloAnthony_FG = [756,691,728,535,688,684,441,669,743,358]
DwightHoward_FG = [468,526,583,560,510,619,416,470,473,251]
ChrisBosh_FG = [549,543,507,615,600,524,393,485,492,343]
ChrisPaul_FG = [407,381,630,631,314,430,425,412,406,568]
KevinDurant_FG = [306,306,587,661,794,711,643,731,849,238]
DerrickRose_FG = [208,208,208,574,672,711,302,0,58,338]
DwayneWade_FG = [699,472,439,854,719,692,416,569,415,509]
#Matrix
FieldGoals  = np.array([KobeBryant_FG, JoeJohnson_FG, LeBronJames_FG, CarmeloAnthony_FG, DwightHoward_FG, ChrisBosh_FG, ChrisPaul_FG, KevinDurant_FG, DerrickRose_FG, DwayneWade_FG])


#Points
KobeBryant_PTS = [2832,2430,2323,2201,1970,2078,1616,2133,83,782]
JoeJohnson_PTS = [1653,1426,1779,1688,1619,1312,1129,1170,1245,1154]
LeBronJames_PTS = [2478,2132,2250,2304,2258,2111,1683,2036,2089,1743]
CarmeloAnthony_PTS = [2122,1881,1978,1504,1943,1970,1245,1920,2112,966]
DwightHoward_PTS = [1292,1443,1695,1624,1503,1784,1113,1296,1297,646]
ChrisBosh_PTS = [1572,1561,1496,1746,1678,1438,1025,1232,1281,928]
ChrisPaul_PTS = [1258,1104,1684,1781,841,1268,1189,1186,1185,1564]
KevinDurant_PTS = [903,903,1624,1871,2472,2161,1850,2280,2593,686]
DerrickRose_PTS = [597,597,597,1361,1619,2026,852,0,159,904]
DwayneWade_PTS = [2040,1397,1254,2386,2045,1941,1082,1463,1028,1331]
#Matrix
Points = np.array([KobeBryant_PTS, JoeJohnson_PTS, LeBronJames_PTS, CarmeloAnthony_PTS, DwightHoward_PTS, ChrisBosh_PTS, ChrisPaul_PTS, KevinDurant_PTS, DerrickRose_PTS, DwayneWade_PTS])             
                  

#Seasons
Seasons = ["2005","2006","2007","2008","2009","2010","2011","2012","2013","2014"]

#Players
Players = ["KobeBryant","JoeJohnson","LeBronJames","CarmeloAnthony","DwightHoward","ChrisBosh","ChrisPaul","KevinDurant","DerrickRose","DwayneWade"]

#Free Throws
KobeBryant_FT = [696,667,623,483,439,483,381,525,18,196]
JoeJohnson_FT = [261,235,316,299,220,195,158,132,159,141]
LeBronJames_FT = [601,489,549,594,593,503,387,403,439,375]
CarmeloAnthony_FT = [573,459,464,371,508,507,295,425,459,189]
DwightHoward_FT = [356,390,529,504,483,546,281,355,349,143]
ChrisBosh_FT = [474,463,472,504,470,384,229,241,223,179]
ChrisPaul_FT = [394,292,332,455,161,337,260,286,295,289]
KevinDurant_FT = [209,209,391,452,756,594,431,679,703,146]
DerrickRose_FT = [146,146,146,197,259,476,194,0,27,152]
DwayneWade_FT = [629,432,354,590,534,494,235,308,189,284]

#Matrix
#
Free_Throws = np.array([KobeBryant_FT, JoeJohnson_FT, LeBronJames_FT, CarmeloAnthony_FG, DwightHoward_FT, ChrisBosh_FT, ChrisPaul_FT, KevinDurant_FT, DerrickRose_FT, DwayneWade_FT])
#

#Free Throw Attempts
KobeBryant_FTA = [819,768,742,564,541,583,451,626,21,241]
JoeJohnson_FTA = [330,314,379,362,269,243,186,161,195,176]
LeBronJames_FTA = [814,701,771,762,773,663,502,535,585,528]
CarmeloAnthony_FTA = [709,568,590,468,612,605,367,512,541,237]
DwightHoward_FTA = [598,666,897,849,816,916,572,721,638,271]
ChrisBosh_FTA = [581,590,559,617,590,471,279,302,272,232]
ChrisPaul_FTA = [465,357,390,524,190,384,302,323,345,321]
KevinDurant_FTA = [256,256,448,524,840,675,501,750,805,171]
DerrickRose_FTA = [205,205,205,250,338,555,239,0,32,187]
DwayneWade_FTA = [803,535,467,771,702,652,297,425,258,370]

#Matrix
#
Free_Throws_Attempts = np.array([KobeBryant_FTA, JoeJohnson_FTA, LeBronJames_FTA, CarmeloAnthony_FTA, DwightHoward_FTA, ChrisBosh_FTA, ChrisPaul_FTA, KevinDurant_FTA, DerrickRose_FTA, DwayneWade_FTA])
#

# %%
def my_func (players, parameter):
    color = {"KobeBryant":'Black',"JoeJohnson":'White',"LeBronJames":'Blue',"CarmeloAnthony":'Red',"DwightHoward":'Yellow',"ChrisBosh":'Green',"ChrisPaul":'Purple',"KevinDurant":'Orange',"DerrickRose":'Brown',"DwayneWade":'Pink'}
    for name in players:
        plt.plot (parameter[Pdict[name]], c=color[name], ls = '--', marker = 's', ms = 7, label = Players[Pdict[name]])
    plt.legend(loc = 'upper left', bbox_to_anchor = (1,1))
    plt.xticks(list(range(0,10)), Seasons)
    plt.show()

# %%
#Free Throws Attempts

Fre_Throws_Attempts_pergame = Free_Throws_Attempts / Games
print(np.matrix.round(Fre_Throws_Attempts_pergame, 2))

print(my_func(Players, Fre_Throws_Attempts_pergame))
# Out:
# [[10.24  9.97  9.05  6.88  7.41  7.11  7.78  8.03  3.5   6.89]
#  [ 4.02  5.51  4.62  4.58  3.54  3.38  3.1   2.24  2.47  2.2 ]
#  [10.3   8.99 10.28  9.41 10.17  8.39  8.1   7.04  7.6   7.65]
#  [ 8.86  8.74  7.66  7.09  8.87  7.86  6.67  7.64  7.03  5.92]
#  [ 7.29  8.12 10.94 10.75  9.95 11.74 10.59  9.49  8.99  6.61]
#  [ 8.3   8.55  8.34  8.01  8.43  6.12  4.89  4.08  3.44  5.27]
#  [ 5.96  5.58  4.88  6.72  4.22  4.8   5.03  4.61  5.56  3.91]
#  [ 7.31  7.31  5.6   7.08 10.24  8.65  7.59  9.26  9.94  6.33]
#  [ 5.12  5.12  5.12  3.09  4.33  6.85  6.13   nan  3.2   3.67]
#  [10.71 10.49  9.16  9.76  9.12  8.58  6.06  6.16  4.78  5.97]]
# C:\Users\johna\AppData\Local\Temp\ipykernel_34772\2201393470.py:3: RuntimeWarning: invalid value encountered in divide
#   Fre_Throws_Attempts_pergame = Free_Throws_Attempts / Games
# None

# %%
def my_func (players, parameter):
    color = {"KobeBryant":'Black',"JoeJohnson":'White',"LeBronJames":'Blue',"CarmeloAnthony":'Red',"DwightHoward":'Yellow',"ChrisBosh":'Green',"ChrisPaul":'Purple',"KevinDurant":'Orange',"DerrickRose":'Brown',"DwayneWade":'Pink'}
    for name in players:
        plt.plot (parameter[Pdict[name]], c=color[name], ls = '--', marker = 's', ms = 7, label = Players[Pdict[name]])
    plt.legend(loc = 'upper left', bbox_to_anchor = (1,1))
    plt.xticks(list(range(0,10)), Seasons)
    plt.show()

# %%
#Accuracy of Free Throws

Accuracy = Free_Throws / Free_Throws_Attempts
print(np.matrix.round(Accuracy, 2))

print(my_func(Players, Accuracy))
# Out:
# C:\Users\johna\AppData\Local\Temp\ipykernel_34772\1024495212.py:3: RuntimeWarning: invalid value encountered in divide
#   Accuracy = Free_Throws / Free_Throws_Attempts
# [[0.85 0.87 0.84 0.86 0.81 0.83 0.84 0.84 0.86 0.81]
#  [0.79 0.75 0.83 0.83 0.82 0.8  0.85 0.82 0.82 0.8 ]
#  [0.74 0.7  0.71 0.78 0.77 0.76 0.77 0.75 0.75 0.71]
#  [1.07 1.22 1.23 1.14 1.12 1.13 1.2  1.31 1.37 1.51]
#  [0.6  0.59 0.59 0.59 0.59 0.6  0.49 0.49 0.55 0.53]
#  [0.82 0.78 0.84 0.82 0.8  0.82 0.82 0.8  0.82 0.77]
#  [0.85 0.82 0.85 0.87 0.85 0.88 0.86 0.89 0.86 0.9 ]
#  [0.82 0.82 0.87 0.86 0.9  0.88 0.86 0.91 0.87 0.85]
#  [0.71 0.71 0.71 0.79 0.77 0.86 0.81  nan 0.84 0.81]
#  [0.78 0.81 0.76 0.77 0.76 0.76 0.79 0.72 0.73 0.77]]
# None

# %%
def my_func (players, parameter):
    color = {"KobeBryant":'Black',"JoeJohnson":'White',"LeBronJames":'Blue',"CarmeloAnthony":'Red',"DwightHoward":'Yellow',"ChrisBosh":'Green',"ChrisPaul":'Purple',"KevinDurant":'Orange',"DerrickRose":'Brown',"DwayneWade":'Pink'}
    for name in players:
        plt.plot (parameter[Pdict[name]], c=color[name], ls = '--', marker = 's', ms = 7, label = Players[Pdict[name]])
    plt.legend(loc = 'upper left', bbox_to_anchor = (1,1))
    plt.xticks(list(range(0,10)), Seasons)
    plt.show()

# %%
#Playing Style

Playing_Style = (Points - Free_Throws) / FieldGoals
print(np.matrix.round(Playing_Style, 2))

print(my_func(Players, Playing_Style))
# Out:
# [[2.18 2.17 2.19 2.15 2.14 2.16 2.15 2.18 2.1  2.2 ]
#  [2.2  2.22 2.26 2.24 2.2  2.17 2.3  2.33 2.35 2.27]
#  [2.15 2.13 2.14 2.17 2.17 2.12 2.09 2.13 2.15 2.19]
#  [1.81 1.72 1.72 1.81 1.82 1.88 1.82 1.87 1.84 1.7 ]
#  [2.   2.   2.   2.   2.   2.   2.   2.   2.   2.  ]
#  [2.   2.02 2.02 2.02 2.01 2.01 2.03 2.04 2.15 2.18]
#  [2.12 2.13 2.15 2.1  2.17 2.17 2.19 2.18 2.19 2.24]
#  [2.27 2.27 2.1  2.15 2.16 2.2  2.21 2.19 2.23 2.27]
#  [2.17 2.17 2.17 2.03 2.02 2.18 2.18  nan 2.28 2.22]
#  [2.02 2.04 2.05 2.1  2.1  2.09 2.04 2.03 2.02 2.06]]
# C:\Users\johna\AppData\Local\Temp\ipykernel_34772\1432579620.py:3: RuntimeWarning: invalid value encountered in divide
#   Playing_Style = (Points - Free_Throws) / FieldGoals
# None
